# %%
import pandas as pd 
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
df = pd.read_csv("retail_store_customer_data.csv")
df
# Out:
#      Store_Location  Customer_Satisfaction Product_Category    Purchase_Type  \
# 0             Rural                    5.6        Groceries  Non-Promotional
# 1       City Center                    9.7         Clothing      Promotional
# 2             Rural                    4.4      Electronics  Non-Promotional
# 3             Rural                    4.2         Clothing      Promotional
# 4       City Center                    9.3         Clothing  Non-Promotional
# ...             ...                    ...              ...              ...
# 1495         Suburb                    7.4      Electronics  Non-Promotional
# 1496         Suburb                    5.7      Electronics      Promotional
# 1497         Suburb                    7.5         Clothing      Promotional
# 1498          Rural                    6.7         Clothing  Non-Promotional
# 1499    City Center                    7.3        Groceries      Promotional
#
#       Amount_Spent
# 0            40.45
# 1            53.20
# 2            42.77
# 3            42.08
# 4            84.25
# ...            ...
# 1495         53.24
# 1496         61.16
# 1497         64.01
# 1498         54.31
# 1499         87.08
#
# [1500 rows x 5 columns]
